# %%
import pandas as pd

data = pd.read_json('terminal.json')
data.columns
# Out:
# Index(['activationCommands', 'activationHooks', 'atomTestRunner', 'author',
#        'bugs', 'consumedServices', 'contributors', 'dependencies',
#        'description', 'deserializers', 'devDependencies', 'downloads',
#        'engines', 'eslintConfig', 'homepage', 'keywords', 'license', 'main',
#        'name', 'package-deps', 'private', 'providedServices', 'readme',
#        'repository', 'scripts', 'stargazers_count', 'theme', 'version'],
#       dtype='object')

# %%
data.loc[:,['name', 'version', 'homepage', 'license', 'downloads', 'stargazers_count']].sort_values(by=['downloads', 'stargazers_count'], ascending=False)
# Out:
#                          name version  \
# 13    platformio-ide-terminal   2.8.4
# 2               terminal-plus  0.14.5
# 12              atom-terminal   0.8.0
# 18        atom-terminal-panel   4.4.4
# 20         open-terminal-here   2.3.2
# 16            terminal-status   1.6.8
# 5            tokamak-terminal  10.0.1
# 1                terminal-tab   0.5.7
# 10            run-in-terminal   1.0.1
# 15          atom-mac-terminal   1.0.4
# 26   atom-terminal-powershell   1.1.0
# 9        terminal-tab-service   0.1.4
# 17            terminal-syntax   0.1.0
# 8                ult-terminal   0.2.2
# 4           terminal-tab-plus  0.5.11
# 21         terminal-panel-uoa  0.5.12
# 0                 vk-terminal   3.0.1
# 3            terminal-to-text   0.1.0
# 7        terminal-like-syntax  0.11.0
# 19        atom-karaf-terminal  0.25.0
# 6              night-terminal   1.1.1
# 11          terminal-commands   1.2.0
# 23          rubinius-terminal   0.0.1
# ...
